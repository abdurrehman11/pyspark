# %%
import findspark
findspark.init('C:/spark/spark-2.4.5-bin-hadoop2.7')

from pyspark.sql import SparkSession
import pyspark

# %%
spark = SparkSession.builder.appName('logreg').getOrCreate()

# %%
from pyspark.ml.classification import LogisticRegression

# %%
my_data = spark.read.format('libsvm').load('sample_libsvm_data.txt')

# %%
my_data.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[124,125,126...|
# |  1.0|(692,[152,153,154...|
# |  1.0|(692,[151,152,153...|
# |  0.0|(692,[129,130,131...|
# |  1.0|(692,[158,159,160...|
# |  1.0|(692,[99,100,101,...|
# |  0.0|(692,[154,155,156...|
# |  0.0|(692,[127,128,129...|
# |  1.0|(692,[154,155,156...|
# |  0.0|(692,[153,154,155...|
# |  0.0|(692,[151,152,153...|
# |  1.0|(692,[129,130,131...|
# |  0.0|(692,[154,155,156...|
# |  1.0|(692,[150,151,152...|
# |  0.0|(692,[124,125,126...|
# |  0.0|(692,[152,153,154...|
# |  1.0|(692,[97,98,99,12...|
# |  1.0|(692,[124,125,126...|
# +-----+--------------------+
# only showing top 20 rows

# %%
my_log_reg_model = LogisticRegression()

# %%
logreg_model = my_log_reg_model.fit(my_data)

# %%
logreg_summary = logreg_model.summary

# %%
logreg_summary.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[127,128,129...|[19.8534775947478...|[0.99999999761359...|       0.0|
# |  1.0|(692,[158,159,160...|[-20.377398194908...|[1.41321555111056...|       1.0|
# |  1.0|(692,[124,125,126...|[-27.401459284891...|[1.25804865126979...|       1.0|
# |  1.0|(692,[152,153,154...|[-18.862741612668...|[6.42710509170303...|       1.0|
# |  1.0|(692,[151,152,153...|[-20.483011833009...|[1.27157209200604...|       1.0|
# |  0.0|(692,[129,130,131...|[19.8506078990277...|[0.99999999760673...|       0.0|
# |  1.0|(692,[158,159,160...|[-20.337256674833...|[1.47109814695581...|       1.0|
# |  1.0|(692,[99,100,101,...|[-19.595579753418...|[3.08850168102631...|       1.0|
# |  0.0|(692,[154,155,156...|[19.2708803215613...|[0.99999999572670...|       0.0|
# |  0.0|(692,[127,128,129...|[23.6202328360422...|[0.99999999994480...|       0.0|
# |  1.0|(692,[154,155,156...|[-24.385235147661...|[2.56818872776510...|       1.0|
# |  0.0|(692,[153,154,155...|[26.3082522490179...|[0.99999999999624...|       0.0|
# |  0.0|(692,[151,152,153...|[25.8329060318703...|[0.99999999999396...|       0.0|
# |  1.0|(692,[129,130,131...|[-19.794609139086...|[2.53110684529575...|       1.0|
# |  0.0|(692,[154,155,156...|[21.0260440948067...|[0.99999999926123...|       0.0|
# |  1.0|(692,[150,151,152...|[-22.764979942873...|[1.29806018790941...|       1.0|
# |  0.0|(692,[124,125,126...|[21.5049307193954...|[0.99999999954235...|       0.0|
# |  0.0|(692,[152,153,154...|[31.9927184226421...|[0.99999999999998...|       0.0|
# |  1.0|(692,[97,98,99,12...|[-20.521067180414...|[1.22409115616505...|       1.0|
# |  1.0|(692,[124,125,126...|[-22.245377742755...|[2.18250475400332...|       1.0|
# +-----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
lr_train, lr_test = my_data.randomSplit([0.7, 0.3])

# %%
final_model = LogisticRegression()

# %%
fit_final = final_model.fit(lr_train)

# %%
prediction_and_labels = fit_final.evaluate(lr_test)

# %%
prediction_and_labels.predictions.show()
# Out:
# +-----+--------------------+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|         probability|prediction|
# +-----+--------------------+--------------------+--------------------+----------+
# |  0.0|(692,[95,96,97,12...|[19.2014861629311...|[0.99999999541963...|       0.0|
# |  0.0|(692,[122,123,124...|[14.5595991546341...|[0.99999952483305...|       0.0|
# |  0.0|(692,[124,125,126...|[-2.9926679771414...|[0.04775821078105...|       1.0|
# |  0.0|(692,[124,125,126...|[21.3400187235319...|[0.99999999946030...|       0.0|
# |  0.0|(692,[124,125,126...|[19.2162323369667...|[0.99999999548667...|       0.0|
# |  0.0|(692,[126,127,128...|[26.4149273113418...|[0.99999999999662...|       0.0|
# |  0.0|(692,[126,127,128...|[24.5999774084628...|[0.99999999997928...|       0.0|
# |  0.0|(692,[127,128,129...|[18.8421099766319...|[0.99999999343891...|       0.0|
# |  0.0|(692,[150,151,152...|[21.0708753905731...|[0.99999999929362...|       0.0|
# |  0.0|(692,[152,153,154...|[14.2633268245898...|[0.99999936097832...|       0.0|
# |  0.0|(692,[154,155,156...|[18.4688354064459...|[0.99999999047013...|       0.0|
# |  0.0|(692,[154,155,156...|[15.1179546789371...|[0.99999972813356...|       0.0|
# |  0.0|(692,[155,156,180...|[13.3246446180137...|[0.99999836627234...|       0.0|
# |  0.0|(692,[181,182,183...|[-11.946623412046...|[6.48103788423283...|       1.0|
# |  0.0|(692,[234,235,237...|[2.48944411232515...|[0.92339849189994...|       0.0|
# |  1.0|(692,[99,100,101,...|[-9.3261572886322...|[8.90558952815635...|       1.0|
# |  1.0|(692,[127,128,129...|[-30.489136901791...|[5.73767685966263...|       1.0|
# |  1.0|(692,[128,129,130...|[-24.220436377869...|[3.02829466738112...|       1.0|
# |  1.0|(692,[128,129,130...|[-23.167186038893...|[8.68198321837528...|       1.0|
# |  1.0|(692,[129,130,131...|[-24.847839254824...|[1.61703911165806...|       1.0|
# +-----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows

# %%
from pyspark.ml.evaluation import (BinaryClassificationEvaluator,
                                   MulticlassClassificationEvaluator)

# %%
my_eval = BinaryClassificationEvaluator()

# %%
my_final_roc = my_eval.evaluate(prediction_and_labels.predictions)

# %%
my_final_roc
# Out:
# 0.9952380952380951
